# %%
import time
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
df = pd.read_csv('../Course/Data/TimeSeriesData/Alcohol_Sales.csv', index_col=0, parse_dates=True)

# %%
df.head()
# Out:
#             S4248SM144NCEN
# DATE
# 1992-01-01            3459
# 1992-02-01            3458
# 1992-03-01            4002
# 1992-04-01            4564
# 1992-05-01            4221

# %%
df.tail()
# Out:
#             S4248SM144NCEN
# DATE
# 2018-09-01           12396
# 2018-10-01           13914
# 2018-11-01           14174
# 2018-12-01           15504
# 2019-01-01           10718

# %%
df = df.dropna()

# %%
df.plot(figsize=(14, 4))

# %%
y = df['S4248SM144NCEN'].values.astype(float)

# %%
test_size = 12

# %%
train_set = y[:-test_size]
test_set = y[-test_size:]

# %%
scaler = MinMaxScaler(feature_range=(-1, 1))

# %%
train_set = scaler.fit_transform(train_set.reshape(-1, 1))

# %%
def prepare_timeseries(series, window_size):
    L = len(series)
    ts = []
    
    for i in range(L - window_size):
        window = series[i : i+window_size].cuda()
        label = series[i+window_size : i+window_size+1].cuda()
        ts.append((window, label))
        
    return ts

# %%
train = torch.FloatTensor(train_set).view(-1)

# %%
window_size = 12

# %%
data = prepare_timeseries(train, window_size)

# %%
len(data)
# Out:
# 301

# %%
class LSTM(nn.Module):
    def __init__(self, input_features=1, hidden_size=128, output_features=1):
        super().__init__()
        self.input_features = input_features
        self.hidden_size = hidden_size
        self.output_features = output_features
        
        self.lstm = nn.LSTM(self.input_features, self.hidden_size)
        
        self.fc1 = nn.Linear(self.hidden_size, self.output_features)
        
        self.hidden = (torch.zeros(1,1, self.hidden_size).cuda(), torch.zeros(1,1, self.hidden_size).cuda())
    
    def forward(self, series):
        out, self.hidden = self.lstm(series.view(len(series), 1, -1), self.hidden)
        
        out = self.fc1(out.view(len(series), -1))
        
        return out[-1]

# %%
model = LSTM().cuda()
criterion = nn.MSELoss().cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
epochs = 100

# %%
start_time = time.time()

for i in range(epochs):
    e_start = time.time()
    
    for series, labels in data:
        optimizer.zero_grad()
        
        model.hidden = (torch.zeros(1, 1, model.hidden_size).cuda(), torch.zeros(1, 1, model.hidden_size).cuda())
        
        pred = model(series)
        loss = criterion(pred, labels)
        
        loss.backward()
        optimizer.step()
    
    e_end = time.time() - e_start
    
    if (i%10)==0 or i==0 or i==(epochs-1):
        print(f"Epoch {i+1}\nLoss: {loss.item():.4f}  Duration: {(e_end/60):.2f} minutes")
    
end_time = time.time() - start_time

print(f"Training Duration {end_time/60} minutes")
# Out:
# Epoch 1
# Loss: 0.2757  Duration: 0.02 minutes
# Epoch 11
# Loss: 0.3293  Duration: 0.02 minutes
# Epoch 21
# Loss: 0.2116  Duration: 0.02 minutes
# Epoch 31
# Loss: 0.0017  Duration: 0.02 minutes
# Epoch 41
# Loss: 0.0008  Duration: 0.02 minutes
# Epoch 51
# Loss: 0.0005  Duration: 0.02 minutes
# Epoch 61
# Loss: 0.0005  Duration: 0.02 minutes
# Epoch 71
# Loss: 0.0001  Duration: 0.03 minutes
# Epoch 81
# Loss: 0.0001  Duration: 0.02 minutes
# Epoch 91
# Loss: 0.0011  Duration: 0.02 minutes
# Epoch 100
# Loss: 0.0009  Duration: 0.02 minutes
# Training Duration 2.224637448787689 minutes

# %%
forecast = 12

preds = train[-window_size:].tolist()

model.eval()

for i in range(forecast):
    seq = torch.FloatTensor(preds[-window_size:]).cuda()
    
    with torch.no_grad():
        model.hidden = (torch.zeros(1, 1, model.hidden_size).cuda(), torch.zeros(1, 1, model.hidden_size).cuda())
        preds.append(model(seq).item())

# %%
true_preds = scaler.inverse_transform(np.array(preds[window_size:]).reshape(-1, 1))

# %%
x = np.arange('2018-02-01', '2019-02-01', dtype='datetime64[M]')

# %%
plt.figure(figsize=(14, 4))
plt.title('Alcohol Sales')
plt.ylabel('Sales (Mil. Dollars)')
plt.grid(True)
plt.autoscale(axis='x', tight=True)
plt.plot(df['S4248SM144NCEN'])
plt.plot(x, true_preds)
plt.show()

# %%
fig = plt.figure(figsize=(14, 4))
plt.title('Alcohol Sales')
plt.ylabel('Sales (Mil. Dollars)')
plt.grid(True)
plt.autoscale(axis='x', tight=True)
fig.autofmt_xdate()
plt.plot(df['S4248SM144NCEN']['2017-07-01':])
plt.plot(x, true_preds)
plt.show()

# %%
epochs = 100

model.train()

y_normalized = scaler.fit_transform(y.reshape(-1, 1))
y_normalized = torch.FloatTensor(y_normalized).view(-1)
full_data = prepare_timeseries(y_normalized, window_size)

# %%
start_time = time.time()

for i in range(epochs):
    e_start = time.time()
    
    for series, labels in full_data:
        optimizer.zero_grad()
        
        model.hidden = (torch.zeros(1, 1, model.hidden_size).cuda(), torch.zeros(1, 1, model.hidden_size).cuda())
        
        pred = model(series)
        loss = criterion(pred, labels)
        
        loss.backward()
        optimizer.step()
    
    e_end = time.time() - e_start
    
    if (i%10)==0 or i==0 or i==(epochs-1):
        print(f"Epoch {i+1}\nLoss: {loss.item():.4f}  Duration: {(e_end/60):.2f} minutes")
    
end_time = time.time() - start_time

print(f"Training Duration {end_time/60} minutes")
# Out:
# Epoch 1
# Loss: 0.0259  Duration: 0.02 minutes
# Epoch 11
# Loss: 0.0026  Duration: 0.03 minutes
# Epoch 21
# Loss: 0.0174  Duration: 0.03 minutes
# Epoch 31
# Loss: 0.0085  Duration: 0.03 minutes
# Epoch 41
# Loss: 0.0026  Duration: 0.03 minutes
# Epoch 51
# Loss: 0.0000  Duration: 0.03 minutes
# Epoch 61
# Loss: 0.0004  Duration: 0.03 minutes
# Epoch 71
# Loss: 0.0001  Duration: 0.03 minutes
# Epoch 81
# Loss: 0.0000  Duration: 0.03 minutes
# Epoch 91
# Loss: 0.0022  Duration: 0.03 minutes
# Epoch 100
# Loss: 0.0000  Duration: 0.03 minutes
# Training Duration 2.567169789473216 minutes

# %%
window_size = 12
forecast = 12
L = len(y)

preds = y_normalized[-window_size:].tolist()

model.eval()

for i in range(forecast):
    seq = torch.FloatTensor(preds[-window_size:]).cuda()
    
    with torch.no_grad():
        model.hidden = (torch.zeros(1, 1, model.hidden_size).cuda(), torch.zeros(1, 1, model.hidden_size).cuda())
        preds.append(model(seq).item())

# %%
true_preds = scaler.inverse_transform(np.array(preds).reshape(-1, 1))

# %%
x = np.arange('2019-02-01', '2020-02-01', dtype='datetime64[M]')

plt.figure(figsize=(14, 4))
plt.title('Alcohol Sales')
plt.ylabel('Sales (Mil. Dollars)')
plt.grid(True)
plt.autoscale(axis='x', tight=True)
plt.plot(df['S4248SM144NCEN'])
plt.plot(x, true_preds[window_size:])
plt.show()

# %%
plt.figure(figsize=(14, 4))
plt.title('Alcohol Sales')
plt.ylabel('Sales (Mil. Dollars)')
plt.grid(True)
plt.autoscale(axis='x', tight=True)
plt.plot(df['S4248SM144NCEN']['2018-01-01':])
plt.plot(x, true_preds[window_size:])
plt.show()
